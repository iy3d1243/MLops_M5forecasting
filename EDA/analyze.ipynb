# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import matplotlib as mpl
import gc 


plt.style.use('ggplot')
mpl.rcParams['figure.dpi'] = 150

# %% [markdown]
# modelisation/eda+api(+frontend)deployment + ci/cd
# testing : pytest(unit test ) / deepchecks(data intergrity and distribution / model evsluation)

# %% [markdown]
# mlops
# bigdata
# cv

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
#downcast for less memory usage 
cols_int16={
    'id': 'int16',
    'item_id': 'int16',
    'dept_id': 'int8',
    'cat_id': 'int8',
    'store_id': 'int8',
    'state_id': 'int8',
    'sales': 'int16',
    'wm_yr_wk': 'int16',
    'month': 'int8',
    'year': 'int16',
    'd': 'int16',
    'event_name_1': 'int8',
    'event_type_1': 'int8',
    'event_name_2': 'int8',
    'event_type_2': 'int8',
    'snap_CA': 'int8',
    'snap_TX': 'int8',
    'snap_WI': 'int8',
    'day': 'int8',
    'sell_price':'float32'
    }

df=pd.read_csv('final.csv',dtype=cols_int16)

# %% [markdown]
# #### info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58327370 entries, 0 to 58327369
# Data columns (total 22 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   id            int16
#  1   item_id       int16
#  2   dept_id       int8
#  3   cat_id        int8
#  4   store_id      int8
#  5   state_id      int8
#  6   wm_yr_wk      int16
#  7   day           int8
#  8   month         int8
#  9   year          int16
#  10  d             int16
#  11  event_name_1  int8
#  12  event_type_1  int8
#  13  event_name_2  int8
#  14  event_type_2  int8
#  15  snap_CA       int8
#  16  snap_TX       int8
#  17  snap_WI       int8
#  18  weekday_cos   float64
#  19  weekday_sin   float64
#  20  sales         int16
#  21  sell_price    float32
# dtypes: float32(1), float64(2), int16(6), int8(13)
# memory usage: 2.4 GB

# %%
df.tail()
# Out:
#              id  item_id  dept_id  cat_id  store_id  state_id  wm_yr_wk  day  \
# 58327365  14329     1432        2       0         9         2     11613   24
# 58327366  14339     1433        2       0         9         2     11613   24
# 58327367  14349     1434        2       0         9         2     11613   24
# 58327368  14359     1435        2       0         9         2     11613   24
# 58327369  14369     1436        2       0         9         2     11613   24
#
#           month  year     d  event_name_1  event_type_1  event_name_2  \
# 58327365      4  2016  1913            19             2             3
# 58327366      4  2016  1913            19             2             3
# 58327367      4  2016  1913            19             2             3
# 58327368      4  2016  1913            19             2             3
# 58327369      4  2016  1913            19             2             3
#
#           event_type_2  snap_CA  snap_TX  snap_WI  weekday_cos  weekday_sin  \
# 58327365             1        0        0        0      0.62349    -0.781831
# 58327366             1        0        0        0      0.62349    -0.781831
# 58327367             1        0        0        0      0.62349    -0.781831
# 58327368             1        0        0        0      0.62349    -0.781831
# 58327369             1        0        0        0      0.62349    -0.781831
#
#           sales  sell_price
# 58327365      1        2.98
# 58327366      0        2.48
# 58327367      0        3.98
# 58327368      3        1.28
# 58327369      0        1.00

# %%
df.describe()
# Out:
#                  id       item_id       dept_id        cat_id      store_id  \
# count  5.832737e+07  5.832737e+07  5.832737e+07  5.832737e+07  5.832737e+07
# mean   1.524450e+04  1.524000e+03  3.161036e+00  8.720892e-01  4.500000e+00
# std    8.801705e+03  8.801704e+02  1.915904e+00  8.934944e-01  2.872281e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    7.622000e+03  7.620000e+02  2.000000e+00  0.000000e+00  2.000000e+00
# 50%    1.524450e+04  1.524000e+03  3.000000e+00  1.000000e+00  4.500000e+00
# 75%    2.286700e+04  2.286000e+03  5.000000e+00  2.000000e+00  7.000000e+00
# max    3.048900e+04  3.048000e+03  6.000000e+00  2.000000e+00  9.000000e+00
#
#            state_id      wm_yr_wk           day         month          year  \
# count  5.832737e+07  5.832737e+07  5.832737e+07  5.832737e+07  5.832737e+07
# mean   9.000000e-01  1.133919e+04  1.570308e+01  6.357554e+00  2.013209e+03
# std    8.306624e-01  1.503742e+02  8.793482e+00  3.458773e+00  1.532086e+00
# min    0.000000e+00  1.110100e+04  1.000000e+00  1.000000e+00  2.011000e+03
# 25%    0.000000e+00  1.121700e+04  8.000000e+00  3.000000e+00  2.012000e+03
# 50%    1.000000e+00  1.133300e+04  1.600000e+01  6.000000e+00  2.013000e+03
# 75%    2.000000e+00  1.144800e+04  2.300000e+01  9.000000e+00  2.015000e+03
# max    2.000000e+00  1.161300e+04  3.100000e+01  1.200000e+01  2.016000e+03
#
#                   d  event_name_1  event_type_1  event_name_2  event_type_2  \
# count  5.832737e+07  5.832737e+07  5.832737e+07  5.832737e+07  5.832737e+07
# mean   9.570000e+02  1.869995e+01  1.980659e+00  2.997386e+00  9.989545e-01
# std    5.522355e+02  2.766177e+00  4.001335e-01  8.851133e-02  4.571503e-02
# min    1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.790000e+02  1.900000e+01  2.000000e+00  3.000000e+00  1.000000e+00
# 50%    9.570000e+02  1.900000e+01  2.000000e+00  3.000000e+00  1.000000e+00
# 75%    1.435000e+03  1.900000e+01  2.000000e+00  3.000000e+00  1.000000e+00
# max    1.913000e+03  3.000000e+01  4.000000e+00  4.000000e+00  2.000000e+00
#
#             snap_CA       snap_TX       snap_WI   weekday_cos   weekday_sin  \
# count  5.832737e+07  5.832737e+07  5.832737e+07  5.832737e+07  5.832737e+07
# mean   3.293257e-01  3.293257e-01  3.293257e-01  2.096021e-04 -9.183269e-04
# std    4.699684e-01  4.699684e-01  4.699684e-01  7.068991e-01  7.073138e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00 -9.009689e-01 -9.749279e-01
# 25%    0.000000e+00  0.000000e+00  0.000000e+00 -9.009689e-01 -7.818315e-01
# 50%    0.000000e+00  0.000000e+00  0.000000e+00 -2.225209e-01  0.000000e+00
# 75%    1.000000e+00  1.000000e+00  1.000000e+00  6.234898e-01  7.818315e-01
# max    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  9.749279e-01
#
#               sales    sell_price
# count  5.832737e+07  5.832737e+07
# mean   1.126322e+00  4.446165e+00
# std    3.873108e+00  3.525359e+00
# min    0.000000e+00  1.000000e-02
# 25%    0.000000e+00  2.180000e+00
# 50%    0.000000e+00  3.420000e+00
# 75%    1.000000e+00  5.840000e+00
# max    7.630000e+02  1.073200e+02

# %% [markdown]
# #### The impact of the sell price on the sales

# %%
plt.scatter(df['sell_price'],df['sales'],
            s=5,          
            linewidth=0,
            color='tab:red',
            edgecolors='none')
plt.xlim(0,40)
plt.ylim(0,500)
plt.title('Sales per sell price')
plt.xlabel('sell price')
plt.ylabel('sales')
plt.show()

# %%
gc.collect()
# Out:
# 3127

# %% [markdown]
# #### The effect of SNAP puchases on sales

# %% [markdown]
# ##### the effect of SNAPS per state

# %%
import pickle as pkl 

with open('validation_le_encoders.pkl','rb')as f: 
    le=pkl.load(f)

for i,j in enumerate(le['state_id'].classes_) : 
    print(f' value {j} encoded as {i}')
# Out:
#  value CA encoded as 0
#  value TX encoded as 1
#  value WI encoded as 2

# %%
df['snap_CA']=((df['state_id']==0) & (df['snap_CA'])).astype('int8')
df['snap_TX']=((df['state_id']==1) & (df['snap_TX'])).astype('int8')
df['snap_WI']=((df['state_id']==2) & (df['snap_WI'])).astype('int8')

# %%
ca=df[df['state_id']==0].groupby('snap_CA')['sales'].mean()
tx=df[df['state_id']==1].groupby('snap_TX')['sales'].mean()
wi=df[df['state_id']==2].groupby('snap_WI')['sales'].mean()

# %%
w=0.35
plt.figure(figsize=(12,6))
plt.bar([0-w,2-w,4-w],[ca.values[0],tx.values[0],wi.values[0]],label='no SNAP',width=0.7)
plt.bar([0+w,2+w,4+w],[ca.values[1],tx.values[1],wi.values[1]],label='SNAP',width=0.7)

plt.xticks([0,2,4],['CA','TX','WI'])
plt.ylabel('average sales')
plt.title('SNAP effect on sales by state')
plt.tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# ##### the effect of SNAPS per item category

# %%
# to study the effect on snap on each item category we need to create a temp column that tells us if 
# that item had snap or not on the day of the purchase , no matter in what state it was 

df['tmp']=((df['snap_CA']) | (df['snap_TX']) | (df['snap_WI'])).astype('int8')

# %%
cat_0=df[df['cat_id']==0].groupby('tmp')['sales'].mean()
cat_1=df[df['cat_id']==1].groupby('tmp')['sales'].mean()
cat_2=df[df['cat_id']==2].groupby('tmp')['sales'].mean()

# %%
w=0.35
plt.figure(figsize=(12,6))
plt.bar([0-w,2-w,4-w],[cat_0.values[0],cat_1.values[0],cat_2.values[0]],label='no SNAP',width=0.7)
plt.bar([0+w,2+w,4+w],[cat_0.values[1],cat_1.values[1],cat_2.values[1]],label='SNAP',width=0.7)

plt.xticks([0,2,4],['FOOD','HOBIES','HOUSEHOLD'])
plt.ylabel('average sales')
plt.title('SNAP effect on sales by item category')
plt.tight_layout()
plt.legend()
plt.show()

# %%
df.drop('tmp',axis=1)
del ca,wi,tx ,cat_0,cat_1,cat_2
gc.collect()
# Out:
# 4557

# %% [markdown]
# #### Total sales per weekday

# %%
df_temp=pd.read_csv('../calendar.csv')

# %%
df_temp['d']=df_temp['d'].str[2:].astype('int16')
df_temp.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year  d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011  2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011  3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011  4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011  5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1

# %%
#merge back the weekday column so i can use it for the plotting 

df=pd.merge(df,
            df_temp[['weekday','d']],
            on='d',
            how='inner'
        )
df.head()
del df_temp
gc.collect()
# Out:
# 0

# %%
days=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['weekday']=pd.Categorical(df['weekday'],days,ordered=True)
df_temp=df.groupby('weekday')['sales'].sum().sort_index()

plt.Figure(figsize=(12,6))
plt.bar(df_temp.index,df_temp.values)
plt.xlabel('Days')
plt.ylabel('Total sales')
plt.title('Total sales per week days')
plt.tight_layout()  
plt.show()
# Out:
# /tmp/ipykernel_1062539/1222465469.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_temp=df.groupby('weekday')['sales'].sum().sort_index()

# %% [markdown]
# #### Sales of each categorie over time

# %%
import pickle as pkl 

with open('validation_le_encoders.pkl','rb')as f: 
    le=pkl.load(f)

for i,j in enumerate(le['cat_id'].classes_) : 
    print(f' value {j} encoded as {i}')
# Out:
#  value FOODS encoded as 0
#  value HOBBIES encoded as 1
#  value HOUSEHOLD encoded as 2

# %%
print(le['cat_id'].classes_)
# Out:
# ['FOODS' 'HOBBIES' 'HOUSEHOLD']

# %%
daily_sales_1 = df[df['cat_id']==0].groupby('d')['sales'].sum()
daily_sales_2 = df[df['cat_id']==1].groupby('d')['sales'].sum()
daily_sales_3 = df[df['cat_id']==2].groupby('d')['sales'].sum()

plt.figure(figsize=(12, 6))
plt.plot(daily_sales_1.index, daily_sales_1.values,label=le['cat_id'].classes_[0])
plt.plot(daily_sales_2.index, daily_sales_2.values,label=le['cat_id'].classes_[1])
plt.plot(daily_sales_3.index, daily_sales_3.values,label=le['cat_id'].classes_[2])
plt.legend()
plt.xlabel('Day')
plt.ylabel('Total Sales')
plt.title('Daily Sales Over Time')
plt.show()

del daily_sales_1,daily_sales_2,daily_sales_3
gc.collect()
# Out:
# 4328

# %%
df2=df[:15_000_000]
daily_sales_1 = df2[df2['cat_id']==0].groupby('d')['sales'].sum()
daily_sales_2 = df2[df2['cat_id']==1].groupby('d')['sales'].sum()
daily_sales_3 = df2[df2['cat_id']==2].groupby('d')['sales'].sum()

plt.figure(figsize=(12, 6))
plt.plot(daily_sales_1.index, daily_sales_1.values,label=le['cat_id'].classes_[0])
plt.plot(daily_sales_2.index, daily_sales_2.values,label=le['cat_id'].classes_[1])
plt.plot(daily_sales_3.index, daily_sales_3.values,label=le['cat_id'].classes_[2])
plt.legend()
plt.xlabel('Day')
plt.ylabel('Total Sales')
plt.title('Daily sales over the first ~500 days')
plt.show()

del daily_sales_1,daily_sales_2,daily_sales_3,df2
gc.collect()
# Out:
# 3909

# %%
gc.collect()
# Out:
# 10

# %%
df.head()
# Out:
#       id  item_id  dept_id  cat_id  store_id  state_id  wm_yr_wk  day  month  \
# 0  14370     1437        3       1         0         0     11101   29      1
# 1  14380     1438        3       1         0         0     11101   29      1
# 2  14390     1439        3       1         0         0     11101   29      1
# 3  14400     1440        3       1         0         0     11101   29      1
# 4  14410     1441        3       1         0         0     11101   29      1
#
#    year  d  event_name_1  event_type_1  event_name_2  event_type_2  snap_CA  \
# 0  2011  1            19             2             3             1        0
# 1  2011  1            19             2             3             1        0
# 2  2011  1            19             2             3             1        0
# 3  2011  1            19             2             3             1        0
# 4  2011  1            19             2             3             1        0
#
#    snap_TX  snap_WI  weekday_cos  weekday_sin  sales  sell_price
# 0        0        0    -0.222521    -0.974928      0        9.58
# 1        0        0    -0.222521    -0.974928      0        3.97
# 2        0        0    -0.222521    -0.974928      0        2.97
# 3        0        0    -0.222521    -0.974928      0        4.34
# 4        0        0    -0.222521    -0.974928      0        2.98

# %%
import pickle as pkl 

with open('calendar_encoders.pkl','rb') as f : 
    le=pkl.load(f)

for i,j in enumerate(le['event_name_1'].classes_) : 
    print(f' value {j} encoded as {i}')
# Out:
#  value Chanukah End encoded as 0
#  value Christmas encoded as 1
#  value Cinco De Mayo encoded as 2
#  value ColumbusDay encoded as 3
#  value Easter encoded as 4
#  value Eid al-Fitr encoded as 5
#  value EidAlAdha encoded as 6
#  value Father's day encoded as 7
#  value Halloween encoded as 8
#  value IndependenceDay encoded as 9
#  value LaborDay encoded as 10
#  value LentStart encoded as 11
#  value LentWeek2 encoded as 12
#  value MartinLutherKingDay encoded as 13
#  value MemorialDay encoded as 14
#  value Mother's day encoded as 15
#  value NBAFinalsEnd encoded as 16
#  value NBAFinalsStart encoded as 17
#  value NewYear encoded as 18
#  value OrthodoxChristmas encoded as 19
#  value OrthodoxEaster encoded as 20
#  value Pesach End encoded as 21
#  value PresidentsDay encoded as 22
#  value Purim End encoded as 23
#  value Ramadan starts encoded as 24
#  value StPatricksDay encoded as 25
#  value SuperBowl encoded as 26
#  value Thanksgiving encoded as 27
#  value ValentinesDay encoded as 28
#  value VeteransDay encoded as 29
#  value nan encoded as 30
